# %%
import chemfit
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Analyzing a real spectrum
#
# This tutorial provides an example of a more realistic analysis than the idealized case considered in the `setup` notebook. The additional considerations explored in this notebook are:
#
# * Handling imperfect flux calibration and discontinuities in flux calibration
# * Adding photometric priors to the fit
# * Handling defects in the observed spectrum
# * Handling poorly modeled lines
# * Line spread function corrections
